# %%
my_number = int(input("Geben Sie bitte eine Zahl ein:"))

if my_number < 10:
    print("zu klein!")
elif my_number in range(10,20+1):
    print("in Ordnung")
else:
    print("zu Hoch!")
# Out:
# zu klein!

# %%
my_name = input("Geben Sie eine Name ein:")
number = int(input("Geben Sie eine zahl ein:"))

for number in range(1,number+1):
    print(my_name)
# Out:
# vasilis
# vasilis
# vasilis

# %%
import random 

number = random.randint(1,50)

benutzer_number = int(input("Geben Sie bitte eine Zahl ein:"))

while benutzer_number < 1 or benutzer_number > 50:
    benutzer_number = int(input("Geben Sie bitte eine Zahl ein:"))

Grün = True

count = 0
while Grün:
    count += 1
    if count == 10:
        print("Sie haben keine Versuche mehr!!")
        print("Hier endet das Programm!!")
        break


    if benutzer_number == number:
        print("Sie haben die Nummer gefunden!!")
        print("Sie haben "+str(count)+" Versuche gehabt!")
        break
    elif benutzer_number < number:
        print("Die Nummer ist kleiner!")
        benutzer_number = int(input("Geben Sie bitte eine andere Zahl ein:"))
        continue
    else:
        print("die Nummer ist großer!!")
        benutzer_number = int(input("Geben Sie bitte eine andere Zahl ein:"))
        continue
# Out:
# die Nummer ist großer!!
# die Nummer ist großer!!
# Die Nummer ist kleiner!
# die Nummer ist großer!!
# die Nummer ist großer!!
# Sie haben die Nummer gefunden!!
# Sie haben 6Versuche gehabt!
